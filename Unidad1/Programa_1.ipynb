# %% [markdown]
# <a href="https://colab.research.google.com/github/Jc-Phantom/Fundamentos-de-programacion/blob/main/Unidad1/Programa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hola mundo")
X=5
X="hello world"
X= True

print("el valor de x es" , X)
# Out:
# hola mundo
# el valor de x es True
