# %% [markdown]
# <a href="https://colab.research.google.com/github/Jc-Phantom/Fundamentos-de-programacion/blob/main/Unidad1/Programa1_elif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#area de un triangulo

b=7
h=10

res=(b*h)/2


print ("el area del triangulo es ", res)

if (res>10):
  print ("buen traigulo")
else:
  print("buenas tardes :)------------")
# Out:
# el area del triangulo es  3.5
# buenas tardes :)------------

# %%
#comparar dos valores
v1=20
v2=11


if (v1 > v2):
  print (v1, "es mayor que" , v2)
else:
   print (v2, "es mayor que" , v1)
# Out:
# 20000 es mayor que 11

# %%
#comparar dos valores
v1=10
v2=10000


if (v1 > v2):
  print (v1, "es mayor que" , v2)
elif v1==v2:
  print (v1, "es igual a" , v2)

else:
   print (v2, "es mayor que" , v1)
# Out:
# 10000 es mayor que 10

# %%
edad = int(input("dame tu edad rapido:  "))

if (edad <= 10):
  print ("eres niño :D")
elif (edad <= 18):
  print ("eres un adolescente" )

elif (edad <= 30):
  print ("eres un adulto joven" )

elif (edad <= 65):
  print ("eres un anciano" )

else:
   print (" Panteon " )
# Out:
# dame tu edad rapido:  20
# eres un adulto joven

# %%
edad = int(input("dame tu edad rapido:  "))

if (edad >= 65):
  print ("eres un anciano" )
elif (edad >= 30):
  print ("eres un adulto joven" )

elif (edad >= 18):
  print ("eres un adolescente" )

elif (edad >= 10):
  print ("eres un niño" )

else:
   print (" eres un niño " )
# Out:
# dame tu edad rapido:  20
# eres un adolescente
