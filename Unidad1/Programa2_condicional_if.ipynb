# %% [markdown]
# <a href="https://colab.research.google.com/github/Jc-Phantom/Fundamentos-de-programacion/blob/main/Unidad1/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#area de un triangulo

b=7
h=10

res=(b*h)/2


print ("el area del triangulo es ", res)

if (res>10):
  print ("buen traigulo")
else:
  print("buenas tardes :)------------")
# Out:
# el area del triangulo es  3.5
# buenas tardes :)------------

# %%
#comparar dos valores
v1=20
v2=11


if (v1 > v2):
  print (v1, "es mayor que" , v2)
else:
   print (v2, "es mayor que" , v1)
# Out:
# 20000 es mayor que 11
